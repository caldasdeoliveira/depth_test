# %%
import numpy as np
import os
import pandas as pd
import run_openpose
import re
import cv2

# %%
# !ls
img_show_flag = True
# Out:
# Photos                    depth_test_notebook.ipynb pose
# __pycache__               openpose_depth_test.py    run_openpose.py

# %%
colors = [ [0,100,255], [0,100,255], [0,255,255], [0,100,255], [0,255,255], [0,100,255],
         [0,255,0], [255,200,100], [255,0,255], [0,255,0], [255,200,100], [255,0,255],
         [0,0,255], [255,0,0], [200,200,0], [255,0,0], [200,200,0], [0,0,0]]

# %%
directory = os.path.join('.','photos')
filename = os.path.join(directory,'annotations.json')

# %%
data=pd.read_json(filename)

# %%
data = data.transpose().reset_index()[['filename','regions','size']]

# %%
protoFile = os.path.join('.','pose','coco','pose_deploy_linevec.prototxt')
weightsFile = os.path.join('.','pose','coco','pose_iter_440000.caffemodel')

# %%
dist_data=[]

# %%
for filename in os.listdir(directory):
    if filename.endswith('.jpg'):
        dist={'Filename': filename, 'Distance': int(re.search('%s(.*)%s' % ('_', 'm'), filename).group(1))}
        print(os.path.join(directory, filename))
        estimate = run_openpose.run_openpose(os.path.join(directory, filename),protoFile,weightsFile)
        f=data['filename']==filename
        d=data['regions'][[i for i, x in enumerate(f) if x][0]]
        for e_point in estimate:
            if e_point:
                idx = e_point[0][3]
                e_x = e_point[0][0]
                e_y = e_point[0][1]
                if (idx > 0) & (idx < 14):
                    if d[idx]['shape_attributes']:
                        x = d[idx]['shape_attributes']['cx']
                        y = d[idx]['shape_attributes']['cy']
                        dist[idx] = np.sqrt((e_x-x)**2+(e_y-y)**2)\
        if img_show_flag:
                frameClone = cv2.imread(filename)
                for e_point in estimate:
                    cv2.circle(frameClone, e_point[0][0:1], 5, colors[i], -1, cv2.LINE_AA)
                    cv2.circle(frameClone, d[e_point[0][3]]['shape_attributes'], 5, colors[i/10], -1, cv2.LINE_AA)
                cv2.imshow("Keypoints",frameClone)
                cv2.waitKey(0)

        dist_data.append(dist)
# Out:
# ./photos/D_3m_2.jpg
# ./photos/D_3m_1.jpg
# ./photos/M_4m_2.jpg
# ./photos/D_7m_2.jpg
# ./photos/M_4m_1.jpg
# ./photos/D_15m_1.jpg
# ./photos/D_7m_1.jpg
# ./photos/M_3m_1.jpg
# ./photos/D_4m_4.jpg
# ./photos/D_4m_5.jpg
# ./photos/D_4m_6.jpg
# ./photos/D_4m_2.jpg
# ./photos/M_15m_1.jpg
# ./photos/M_7m_2.jpg
# ./photos/D_4m_3.jpg
# ./photos/D_4m_1.jpg
# ./photos/M_15m_2.jpg
# ./photos/M_7m_1.jpg

# %%
pd.DataFrame(dist_data)
# Out:
#        Filename  Distance          1          2          3            4  \
# 0    D_3m_2.jpg         3  78.873316  71.840100  15.620499     6.708204
# 1    D_3m_1.jpg         3  34.828150  18.110770  42.544095    50.219518
# 2    M_4m_2.jpg         4  36.400549  22.803509  26.570661    42.638011
# 3    D_7m_2.jpg         7  42.011903  24.207437  70.342022    43.931765
